# %% [markdown]
# # Environmental Quality Index (EQI) for California Counties
# **Author:** Shilpa Kannan
# **Last Updated:** October 5, 2025
#
# ---
#
# ## 1. Introduction
#
# ### Objective
# The purpose of this notebook is to perform the initial data loading, exploration, and cleaning of the three primary datasets for the EQI project.
#
# ### Plan
# 1. **Introduction**
# 2. **Setup:** Import necessary libraries.
# 3. **Data Loading:** Load the CDC, EPA, and Census datasets from their CSV files.
# 4. **Initial Exploration:** Inspect each DataFrame to understand its structure, identify missing values, and check data types.
# 5. **Initial Cleaning:** Perform basic cleaning tasks such as filtering, renaming columns, and handling missing data.

# %% [markdown]
# ## 2. Setup

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import numpy as np
import matplotlib.pyplot as plt
import geopandas as gpd
import seaborn as sns
from scipy.stats import pearsonr

# %% [markdown]
# ## 3. Data Loading

# %%
# Define file paths
CDC_HEALTH_DATA_PATH = '../data/cdc_places_county_california_2024.csv'
EPA_AQI_DATA_PATH = '../data/epa_aqi_county_usa_2024.csv'
CENSUS_DATA_PATH = '../data/census_economic_county_california_2024.csv'

# Load the data into DataFrames
cdc_health_df = pd.read_csv(CDC_HEALTH_DATA_PATH)
epa_aqi_df = pd.read_csv(EPA_AQI_DATA_PATH)
census_economic_df = pd.read_csv(CENSUS_DATA_PATH)

print("Datasets loaded successfully!")
# Out:
# Datasets loaded successfully!

# %% [markdown]
# ## 4. Initial Data Exploration

# %% [markdown]
# ### 4.1 Exploration of CDC Health Data

# %%
cdc_health_df.head()
# Out:
#    Year StateAbbr   StateDesc LocationName DataSource         Category  \
# 0  2022        CA  California        Butte      BRFSS  Health Outcomes
# 1  2022        CA  California    Calaveras      BRFSS  Health Outcomes
# 2  2022        CA  California     Imperial      BRFSS  Health Outcomes
# 3  2022        CA  California         Kern      BRFSS    Health Status
# 4  2022        CA  California         Lake      BRFSS  Health Outcomes
#
#                                  Measure Data_Value_Unit  \
# 0                    Stroke among adults               %
# 1        Diagnosed diabetes among adults               %
# 2                Depression among adults               %
# 3  Frequent mental distress among adults               %
# 4            Current asthma among adults               %
#
#            Data_Value_Type  Data_Value  ...  Low_Confidence_Limit  \
# 0  Age-adjusted prevalence         3.2  ...                   2.9
# 1  Age-adjusted prevalence         9.4  ...                   8.1
# 2  Age-adjusted prevalence        20.7  ...                  17.5
# 3         Crude prevalence        18.8  ...                  17.0
# 4         Crude prevalence        10.8  ...                   9.6
#
#    High_Confidence_Limit  TotalPopulation  TotalPop18plus LocationID  \
# 0                    3.5          207,303         165,784       6007
# 1                   10.8           46,563          38,508       6009
# 2                   24.2          178,713         128,478       6025
# 3                   20.6          916,108         655,754       6029
# 4                   12.2           68,191          53,338       6033
#
#   CategoryID   MeasureId DataValueTypeID       Short_Question_Text  \
# 0    HLTHOUT      STROKE       AgeAdjPrv                    Stroke
# 1    HLTHOUT    DIABETES       AgeAdjPrv                  Diabetes
# 2    HLTHOUT  DEPRESSION       AgeAdjPrv                Depression
# 3   HLTHSTAT       MHLTH          CrdPrv  Frequent Mental Distress
# 4    HLTHOUT     CASTHMA          CrdPrv            Current Asthma
#
#                                   Geolocation
# 0   POINT (-121.60115169224 39.6663795928272)
# 1  POINT (-120.554047814815 38.2047708244318)
# 2  POINT (-115.365089023702 33.0401896009011)
# 3  POINT (-118.730029086317 35.3428262386385)
# 4  POINT (-122.753413599125 39.0999886976907)
#
# [5 rows x 22 columns]

# %%
cdc_health_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4640 entries, 0 to 4639
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Year                        4640 non-null   int64
#  1   StateAbbr                   4640 non-null   object
#  2   StateDesc                   4640 non-null   object
#  3   LocationName                4640 non-null   object
#  4   DataSource                  4640 non-null   object
#  5   Category                    4640 non-null   object
#  6   Measure                     4640 non-null   object
#  7   Data_Value_Unit             4640 non-null   object
#  8   Data_Value_Type             4640 non-null   object
#  9   Data_Value                  4640 non-null   float64
#  10  Data_Value_Footnote_Symbol  0 non-null      float64
#  11  Data_Value_Footnote         0 non-null      float64
#  12  Low_Confidence_Limit        4640 non-null   float64
#  13  High_Confidence_Limit       4640 non-null   float64
#  14  TotalPopulation             4640 non-null   object
#  15  TotalPop18plus              4640 non-null   object
#  16  LocationID                  4640 non-null   int64
#  17  CategoryID                  4640 non-null   object
#  18  MeasureId                   4640 non-null   object
#  19  DataValueTypeID             4640 non-null   object
#  20  Short_Question_Text         4640 non-null   object
#  21  Geolocation                 4640 non-null   object
# dtypes: float64(5), int64(2), object(15)
# memory usage: 797.6+ KB

# %% [markdown]
# **Observation:** The `cdc_health_df` DataFrame was explored with the following findings:
# 1.  **Missing Values:** The dataset contains no missing values.
# 2.  **Unnecessary Columns:** It includes several "footnote" columns that are not useful for analysis and should be removed during the cleaning stage.

# %% [markdown]
# ### 4.2 Exploration of EPA Air Quality Data

# %%
epa_aqi_df.head()
# Out:
#      State   County  Year  Days with AQI  Good Days  Moderate Days  \
# 0  Alabama  Baldwin  2024            355        278             77
# 1  Alabama     Clay  2024            354        307             47
# 2  Alabama   DeKalb  2024            366        277             89
# 3  Alabama   Elmore  2024            234        231              3
# 4  Alabama   Etowah  2024            362        212            150
#
#    Unhealthy for Sensitive Groups Days  Unhealthy Days  Very Unhealthy Days  \
# 0                                    0               0                    0
# 1                                    0               0                    0
# 2                                    0               0                    0
# 3                                    0               0                    0
# 4                                    0               0                    0
#
#    Hazardous Days  Max AQI  90th Percentile AQI  Median AQI  Days CO  \
# 0               0       90                   58          40        0
# 1               0       75                   52          29        0
# 2               0       87                   57          43        0
# 3               0       58                   46          37        0
# 4               0       93                   60          47        0
#
#    Days NO2  Days Ozone  Days PM2.5  Days PM10
# 0         0         127         228          0
# 1         0           0         354          0
# 2         0         242         124          0
# 3         0         234           0          0
# 4         0          84         278          0

# %%
epa_aqi_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 995 entries, 0 to 994
# Data columns (total 18 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   State                                995 non-null    object
#  1   County                               995 non-null    object
#  2   Year                                 995 non-null    int64
#  3   Days with AQI                        995 non-null    int64
#  4   Good Days                            995 non-null    int64
#  5   Moderate Days                        995 non-null    int64
#  6   Unhealthy for Sensitive Groups Days  995 non-null    int64
#  7   Unhealthy Days                       995 non-null    int64
#  8   Very Unhealthy Days                  995 non-null    int64
#  9   Hazardous Days                       995 non-null    int64
#  10  Max AQI                              995 non-null    int64
#  11  90th Percentile AQI                  995 non-null    int64
#  12  Median AQI                           995 non-null    int64
#  13  Days CO                              995 non-null    int64
#  14  Days NO2                             995 non-null    int64
#  15  Days Ozone                           995 non-null    int64
#  16  Days PM2.5                           995 non-null    int64
#  17  Days PM10                            995 non-null    int64
# dtypes: int64(16), object(2)
# memory usage: 140.1+ KB

# %% [markdown]
# **Observation:** The `epa_aqi_df` DataFrame was explored with the following findings:
# 1.  **Missing Values:** The dataset contains no missing values.
# 2.  **Data Scope:** The dataset covers the entire United States and will need to be filtered to only include California during the cleaning stage.

# %% [markdown]
# ### 4.3 Exploration of Census Economic Data

# %%
census_economic_df.head()
# Out:
#            GEO_ID                             NAME  \
# 0       Geography             Geographic Area Name
# 1  0500000US06001       Alameda County, California
# 2  0500000US06007         Butte County, California
# 3  0500000US06013  Contra Costa County, California
# 4  0500000US06017     El Dorado County, California
#
#                                           DP03_0001E  \
# 0  Estimate!!EMPLOYMENT STATUS!!Population 16 yea...
# 1                                            1372398
# 2                                             171256
# 3                                             954525
# 4                                             160464
#
#                                           DP03_0001M  \
# 0  Margin of Error!!EMPLOYMENT STATUS!!Population...
# 1                                               2344
# 2                                                813
# 3                                               1860
# 4                                                718
#
#                                           DP03_0002E  \
# 0  Estimate!!EMPLOYMENT STATUS!!Population 16 yea...
# 1                                             924414
# 2                                             101653
# 3                                             608716
# 4                                              94375
#
#                                           DP03_0002M  \
# 0  Margin of Error!!EMPLOYMENT STATUS!!Population...
# 1                                               8513
# 2                                               3075
# 3                                               8124
# 4                                               3039
#
#                                           DP03_0003E  \
# 0  Estimate!!EMPLOYMENT STATUS!!Population 16 yea...
# 1                                             921327
# 2                                             101653
# 3                                             607801
# 4                                              94375
#
#                                           DP03_0003M  \
# 0  Margin of Error!!EMPLOYMENT STATUS!!Population...
# 1                                               8617
# 2                                               3075
# 3                                               8019
# 4                                               3039
#
#                                           DP03_0004E  \
# 0  Estimate!!EMPLOYMENT STATUS!!Population 16 yea...
# 1                                             876021
# 2                                              93926
# 3                                             561466
# 4                                              91737
#
#                                           DP03_0004M  ...  \
# 0  Margin of Error!!EMPLOYMENT STATUS!!Population...  ...
# 1                                               9705  ...
# 2                                               3257  ...
# 3                                               8348  ...
# 4                                               3094  ...
#
#                                          DP03_0133PM  \
# 0  Percent Margin of Error!!PERCENTAGE OF FAMILIE...
# 1                                                0.6
# 2                                                2.0
# 3                                                0.8
# 4                                                1.4
#
#                                          DP03_0134PE  \
# 0  Percent!!PERCENTAGE OF FAMILIES AND PEOPLE WHO...
# 1                                                8.3
# 2                                               21.7
# 3                                                8.4
# 4                                                8.7
#
#                                          DP03_0134PM  \
# 0  Percent Margin of Error!!PERCENTAGE OF FAMILIE...
# 1                                                0.6
# 2                                                2.6
# 3                                                1.1
# 4                                                1.9
#
#                                          DP03_0135PE  \
# 0  Percent!!PERCENTAGE OF FAMILIES AND PEOPLE WHO...
# 1                                               11.5
# 2                                                8.7
# 3                                                6.8
# 4                                                5.6
#
#                                          DP03_0135PM  \
# 0  Percent Margin of Error!!PERCENTAGE OF FAMILIE...
# 1                                                1.2
# 2                                                2.3
# 3                                                1.2
# 4                                                1.7
#
#                                          DP03_0136PE  \
# 0  Percent!!PERCENTAGE OF FAMILIES AND PEOPLE WHO...
# 1                                                5.1
# 2                                               13.8
# 3                                                6.6
# 4                                                5.4
#
#                                          DP03_0136PM  \
# 0  Percent Margin of Error!!PERCENTAGE OF FAMILIE...
# 1                                                0.7
# 2                                                3.3
# 3                                                1.2
# 4                                                1.9
#
#                                          DP03_0137PE  \
# 0  Percent!!PERCENTAGE OF FAMILIES AND PEOPLE WHO...
# 1                                               21.6
# 2                                               33.1
# 3                                               18.5
# 4                                               18.9
#
#                                          DP03_0137PM Unnamed: 550
# 0  Percent Margin of Error!!PERCENTAGE OF FAMILIE...          NaN
# 1                                                1.4          NaN
# 2                                                3.7          NaN
# 3                                                1.9          NaN
# 4                                                3.8          NaN
#
# [5 rows x 551 columns]

# %%
census_economic_df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 551 columns):
#  #    Column        Dtype
# ---   ------        -----
#  0    GEO_ID        object
#  1    NAME          object
#  2    DP03_0001E    object
#  3    DP03_0001M    object
#  4    DP03_0002E    object
#  5    DP03_0002M    object
#  6    DP03_0003E    object
#  7    DP03_0003M    object
#  8    DP03_0004E    object
#  9    DP03_0004M    object
#  10   DP03_0005E    object
#  11   DP03_0005M    object
#  12   DP03_0006E    object
#  13   DP03_0006M    object
#  14   DP03_0007E    object
#  15   DP03_0007M    object
#  16   DP03_0008E    object
#  17   DP03_0008M    object
#  18   DP03_0009E    object
#  19   DP03_0009M    object
#  20   DP03_0010E    object
#  21   DP03_0010M    object
#  22   DP03_0011E    object
#  23   DP03_0011M    object
#  24   DP03_0012E    object
#  25   DP03_0012M    object
#  26   DP03_0013E    object
#  27   DP03_0013M    object
#  28   DP03_0014E    object
#  29   DP03_0014M    object
#  30   DP03_0015E    object
#  31   DP03_0015M    object
#  32   DP03_0016E    object
#  33   DP03_0016M    object
#  34   DP03_0017E    object
#  35   DP03_0017M    object
#  36   DP03_0018E    object
#  37   DP03_0018M    object
#  38   DP03_0019E    object
#  39   DP03_0019M    object
#  40   DP03_0020E    object
#  41   DP03_0020M    object
#  42   DP03_0021E    object
#  43   DP03_0021M    object
#  44   DP03_0022E    object
#  45   DP03_0022M    object
#  46   DP03_0023E    object
#  47   DP03_0023M    object
#  48   DP03_0024E    object
#  49   DP03_0024M    object
#  50   DP03_0025E    object
#  51   DP03_0025M    object
#  52   DP03_0026E    object
#  53   DP03_0026M    object
#  54   DP03_0027E    object
#  55   DP03_0027M    object
#  56   DP03_0028E    object
#  57   DP03_0028M    object
#  58   DP03_0029E    object
#  59   DP03_0029M    object
#  60   DP03_0030E    object
#  61   DP03_0030M    object
#  62   DP03_0031E    object
#  63   DP03_0031M    object
#  64   DP03_0032E    object
#  65   DP03_0032M    object
#  66   DP03_0033E    object
#  67   DP03_0033M    object
#  68   DP03_0034E    object
#  69   DP03_0034M    object
#  70   DP03_0035E    object
#  71   DP03_0035M    object
#  72   DP03_0036E    object
#  73   DP03_0036M    object
#  74   DP03_0037E    object
#  75   DP03_0037M    object
#  76   DP03_0038E    object
#  77   DP03_0038M    object
#  78   DP03_0039E    object
#  79   DP03_0039M    object
#  80   DP03_0040E    object
#  81   DP03_0040M    object
#  82   DP03_0041E    object
#  83   DP03_0041M    object
#  84   DP03_0042E    object
#  85   DP03_0042M    object
#  86   DP03_0043E    object
#  87   DP03_0043M    object
#  88   DP03_0044E    object
#  89   DP03_0044M    object
#  90   DP03_0045E    object
#  91   DP03_0045M    object
#  92   DP03_0046E    object
#  93   DP03_0046M    object
#  94   DP03_0047E    object
#  95   DP03_0047M    object
#  96   DP03_0048E    object
#  97   DP03_0048M    object
#  98   DP03_0049E    object
#  99   DP03_0049M    object
#  100  DP03_0050E    object
#  101  DP03_0050M    object
#  102  DP03_0051E    object
#  103  DP03_0051M    object
#  104  DP03_0052E    object
#  105  DP03_0052M    object
#  106  DP03_0053E    object
#  107  DP03_0053M    object
#  108  DP03_0054E    object
#  109  DP03_0054M    object
#  110  DP03_0055E    object
#  111  DP03_0055M    object
#  112  DP03_0056E    object
#  113  DP03_0056M    object
#  114  DP03_0057E    object
#  115  DP03_0057M    object
#  116  DP03_0058E    object
#  117  DP03_0058M    object
#  118  DP03_0059E    object
#  119  DP03_0059M    object
#  120  DP03_0060E    object
#  121  DP03_0060M    object
#  122  DP03_0061E    object
#  123  DP03_0061M    object
#  124  DP03_0062E    object
#  125  DP03_0062M    object
#  126  DP03_0063E    object
#  127  DP03_0063M    object
#  128  DP03_0064E    object
#  129  DP03_0064M    object
#  130  DP03_0065E    object
#  131  DP03_0065M    object
#  132  DP03_0066E    object
#  133  DP03_0066M    object
#  134  DP03_0067E    object
#  135  DP03_0067M    object
#  136  DP03_0068E    object
#  137  DP03_0068M    object
#  138  DP03_0069E    object
#  139  DP03_0069M    object
#  140  DP03_0070E    object
#  141  DP03_0070M    object
#  142  DP03_0071E    object
#  143  DP03_0071M    object
#  144  DP03_0072E    object
#  145  DP03_0072M    object
#  146  DP03_0073E    object
#  147  DP03_0073M    object
#  148  DP03_0074E    object
#  149  DP03_0074M    object
#  150  DP03_0075E    object
#  151  DP03_0075M    object
#  152  DP03_0076E    object
#  153  DP03_0076M    object
#  154  DP03_0077E    object
#  155  DP03_0077M    object
#  156  DP03_0078E    object
#  157  DP03_0078M    object
#  158  DP03_0079E    object
#  159  DP03_0079M    object
#  160  DP03_0080E    object
#  161  DP03_0080M    object
#  162  DP03_0081E    object
#  163  DP03_0081M    object
#  164  DP03_0082E    object
#  165  DP03_0082M    object
#  166  DP03_0083E    object
#  167  DP03_0083M    object
#  168  DP03_0084E    object
#  169  DP03_0084M    object
#  170  DP03_0085E    object
#  171  DP03_0085M    object
#  172  DP03_0086E    object
#  173  DP03_0086M    object
#  174  DP03_0087E    object
#  175  DP03_0087M    object
#  176  DP03_0088E    object
#  177  DP03_0088M    object
#  178  DP03_0089E    object
#  179  DP03_0089M    object
#  180  DP03_0090E    object
#  181  DP03_0090M    object
#  182  DP03_0091E    object
#  183  DP03_0091M    object
#  184  DP03_0092E    object
#  185  DP03_0092M    object
#  186  DP03_0093E    object
#  187  DP03_0093M    object
#  188  DP03_0094E    object
#  189  DP03_0094M    object
#  190  DP03_0095E    object
#  191  DP03_0095M    object
#  192  DP03_0096E    object
#  193  DP03_0096M    object
#  194  DP03_0097E    object
#  195  DP03_0097M    object
#  196  DP03_0098E    object
#  197  DP03_0098M    object
#  198  DP03_0099E    object
#  199  DP03_0099M    object
#  200  DP03_0100E    object
#  201  DP03_0100M    object
#  202  DP03_0101E    object
#  203  DP03_0101M    object
#  204  DP03_0102E    object
#  205  DP03_0102M    object
#  206  DP03_0103E    object
#  207  DP03_0103M    object
#  208  DP03_0104E    object
#  209  DP03_0104M    object
#  210  DP03_0105E    object
#  211  DP03_0105M    object
#  212  DP03_0106E    object
#  213  DP03_0106M    object
#  214  DP03_0107E    object
#  215  DP03_0107M    object
#  216  DP03_0108E    object
#  217  DP03_0108M    object
#  218  DP03_0109E    object
#  219  DP03_0109M    object
#  220  DP03_0110E    object
#  221  DP03_0110M    object
#  222  DP03_0111E    object
#  223  DP03_0111M    object
#  224  DP03_0112E    object
#  225  DP03_0112M    object
#  226  DP03_0113E    object
#  227  DP03_0113M    object
#  228  DP03_0114E    object
#  229  DP03_0114M    object
#  230  DP03_0115E    object
#  231  DP03_0115M    object
#  232  DP03_0116E    object
#  233  DP03_0116M    object
#  234  DP03_0117E    object
#  235  DP03_0117M    object
#  236  DP03_0118E    object
#  237  DP03_0118M    object
#  238  DP03_0119E    object
#  239  DP03_0119M    object
#  240  DP03_0120E    object
#  241  DP03_0120M    object
#  242  DP03_0121E    object
#  243  DP03_0121M    object
#  244  DP03_0122E    object
#  245  DP03_0122M    object
#  246  DP03_0123E    object
#  247  DP03_0123M    object
#  248  DP03_0124E    object
#  249  DP03_0124M    object
#  250  DP03_0125E    object
#  251  DP03_0125M    object
#  252  DP03_0126E    object
#  253  DP03_0126M    object
#  254  DP03_0127E    object
#  255  DP03_0127M    object
#  256  DP03_0128E    object
#  257  DP03_0128M    object
#  258  DP03_0129E    object
#  259  DP03_0129M    object
#  260  DP03_0130E    object
#  261  DP03_0130M    object
#  262  DP03_0131E    object
#  263  DP03_0131M    object
#  264  DP03_0132E    object
#  265  DP03_0132M    object
#  266  DP03_0133E    object
#  267  DP03_0133M    object
#  268  DP03_0134E    object
#  269  DP03_0134M    object
#  270  DP03_0135E    object
#  271  DP03_0135M    object
#  272  DP03_0136E    object
#  273  DP03_0136M    object
#  274  DP03_0137E    object
#  275  DP03_0137M    object
#  276  DP03_0001PE   object
#  277  DP03_0001PM   object
#  278  DP03_0002PE   object
#  279  DP03_0002PM   object
#  280  DP03_0003PE   object
#  281  DP03_0003PM   object
#  282  DP03_0004PE   object
#  283  DP03_0004PM   object
#  284  DP03_0005PE   object
#  285  DP03_0005PM   object
#  286  DP03_0006PE   object
#  287  DP03_0006PM   object
#  288  DP03_0007PE   object
#  289  DP03_0007PM   object
#  290  DP03_0008PE   object
#  291  DP03_0008PM   object
#  292  DP03_0009PE   object
#  293  DP03_0009PM   object
#  294  DP03_0010PE   object
#  295  DP03_0010PM   object
#  296  DP03_0011PE   object
#  297  DP03_0011PM   object
#  298  DP03_0012PE   object
#  299  DP03_0012PM   object
#  300  DP03_0013PE   object
#  301  DP03_0013PM   object
#  302  DP03_0014PE   object
#  303  DP03_0014PM   object
#  304  DP03_0015PE   object
#  305  DP03_0015PM   object
#  306  DP03_0016PE   object
#  307  DP03_0016PM   object
#  308  DP03_0017PE   object
#  309  DP03_0017PM   object
#  310  DP03_0018PE   object
#  311  DP03_0018PM   object
#  312  DP03_0019PE   object
#  313  DP03_0019PM   object
#  314  DP03_0020PE   object
#  315  DP03_0020PM   object
#  316  DP03_0021PE   object
#  317  DP03_0021PM   object
#  318  DP03_0022PE   object
#  319  DP03_0022PM   object
#  320  DP03_0023PE   object
#  321  DP03_0023PM   object
#  322  DP03_0024PE   object
#  323  DP03_0024PM   object
#  324  DP03_0025PE   object
#  325  DP03_0025PM   object
#  326  DP03_0026PE   object
#  327  DP03_0026PM   object
#  328  DP03_0027PE   object
#  329  DP03_0027PM   object
#  330  DP03_0028PE   object
#  331  DP03_0028PM   object
#  332  DP03_0029PE   object
#  333  DP03_0029PM   object
#  334  DP03_0030PE   object
#  335  DP03_0030PM   object
#  336  DP03_0031PE   object
#  337  DP03_0031PM   object
#  338  DP03_0032PE   object
#  339  DP03_0032PM   object
#  340  DP03_0033PE   object
#  341  DP03_0033PM   object
#  342  DP03_0034PE   object
#  343  DP03_0034PM   object
#  344  DP03_0035PE   object
#  345  DP03_0035PM   object
#  346  DP03_0036PE   object
#  347  DP03_0036PM   object
#  348  DP03_0037PE   object
#  349  DP03_0037PM   object
#  350  DP03_0038PE   object
#  351  DP03_0038PM   object
#  352  DP03_0039PE   object
#  353  DP03_0039PM   object
#  354  DP03_0040PE   object
#  355  DP03_0040PM   object
#  356  DP03_0041PE   object
#  357  DP03_0041PM   object
#  358  DP03_0042PE   object
#  359  DP03_0042PM   object
#  360  DP03_0043PE   object
#  361  DP03_0043PM   object
#  362  DP03_0044PE   object
#  363  DP03_0044PM   object
#  364  DP03_0045PE   object
#  365  DP03_0045PM   object
#  366  DP03_0046PE   object
#  367  DP03_0046PM   object
#  368  DP03_0047PE   object
#  369  DP03_0047PM   object
#  370  DP03_0048PE   object
#  371  DP03_0048PM   object
#  372  DP03_0049PE   object
#  373  DP03_0049PM   object
#  374  DP03_0050PE   object
#  375  DP03_0050PM   object
#  376  DP03_0051PE   object
#  377  DP03_0051PM   object
#  378  DP03_0052PE   object
#  379  DP03_0052PM   object
#  380  DP03_0053PE   object
#  381  DP03_0053PM   object
#  382  DP03_0054PE   object
#  383  DP03_0054PM   object
#  384  DP03_0055PE   object
#  385  DP03_0055PM   object
#  386  DP03_0056PE   object
#  387  DP03_0056PM   object
#  388  DP03_0057PE   object
#  389  DP03_0057PM   object
#  390  DP03_0058PE   object
#  391  DP03_0058PM   object
#  392  DP03_0059PE   object
#  393  DP03_0059PM   object
#  394  DP03_0060PE   object
#  395  DP03_0060PM   object
#  396  DP03_0061PE   object
#  397  DP03_0061PM   object
#  398  DP03_0062PE   object
#  399  DP03_0062PM   object
#  400  DP03_0063PE   object
#  401  DP03_0063PM   object
#  402  DP03_0064PE   object
#  403  DP03_0064PM   object
#  404  DP03_0065PE   object
#  405  DP03_0065PM   object
#  406  DP03_0066PE   object
#  407  DP03_0066PM   object
#  408  DP03_0067PE   object
#  409  DP03_0067PM   object
#  410  DP03_0068PE   object
#  411  DP03_0068PM   object
#  412  DP03_0069PE   object
#  413  DP03_0069PM   object
#  414  DP03_0070PE   object
#  415  DP03_0070PM   object
#  416  DP03_0071PE   object
#  417  DP03_0071PM   object
#  418  DP03_0072PE   object
#  419  DP03_0072PM   object
#  420  DP03_0073PE   object
#  421  DP03_0073PM   object
#  422  DP03_0074PE   object
#  423  DP03_0074PM   object
#  424  DP03_0075PE   object
#  425  DP03_0075PM   object
#  426  DP03_0076PE   object
#  427  DP03_0076PM   object
#  428  DP03_0077PE   object
#  429  DP03_0077PM   object
#  430  DP03_0078PE   object
#  431  DP03_0078PM   object
#  432  DP03_0079PE   object
#  433  DP03_0079PM   object
#  434  DP03_0080PE   object
#  435  DP03_0080PM   object
#  436  DP03_0081PE   object
#  437  DP03_0081PM   object
#  438  DP03_0082PE   object
#  439  DP03_0082PM   object
#  440  DP03_0083PE   object
#  441  DP03_0083PM   object
#  442  DP03_0084PE   object
#  443  DP03_0084PM   object
#  444  DP03_0085PE   object
#  445  DP03_0085PM   object
#  446  DP03_0086PE   object
#  447  DP03_0086PM   object
#  448  DP03_0087PE   object
#  449  DP03_0087PM   object
#  450  DP03_0088PE   object
#  451  DP03_0088PM   object
#  452  DP03_0089PE   object
#  453  DP03_0089PM   object
#  454  DP03_0090PE   object
#  455  DP03_0090PM   object
#  456  DP03_0091PE   object
#  457  DP03_0091PM   object
#  458  DP03_0092PE   object
#  459  DP03_0092PM   object
#  460  DP03_0093PE   object
#  461  DP03_0093PM   object
#  462  DP03_0094PE   object
#  463  DP03_0094PM   object
#  464  DP03_0095PE   object
#  465  DP03_0095PM   object
#  466  DP03_0096PE   object
#  467  DP03_0096PM   object
#  468  DP03_0097PE   object
#  469  DP03_0097PM   object
#  470  DP03_0098PE   object
#  471  DP03_0098PM   object
#  472  DP03_0099PE   object
#  473  DP03_0099PM   object
#  474  DP03_0100PE   object
#  475  DP03_0100PM   object
#  476  DP03_0101PE   object
#  477  DP03_0101PM   object
#  478  DP03_0102PE   object
#  479  DP03_0102PM   object
#  480  DP03_0103PE   object
#  481  DP03_0103PM   object
#  482  DP03_0104PE   object
#  483  DP03_0104PM   object
#  484  DP03_0105PE   object
#  485  DP03_0105PM   object
#  486  DP03_0106PE   object
#  487  DP03_0106PM   object
#  488  DP03_0107PE   object
#  489  DP03_0107PM   object
#  490  DP03_0108PE   object
#  491  DP03_0108PM   object
#  492  DP03_0109PE   object
#  493  DP03_0109PM   object
#  494  DP03_0110PE   object
#  495  DP03_0110PM   object
#  496  DP03_0111PE   object
#  497  DP03_0111PM   object
#  498  DP03_0112PE   object
#  499  DP03_0112PM   object
#  500  DP03_0113PE   object
#  501  DP03_0113PM   object
#  502  DP03_0114PE   object
#  503  DP03_0114PM   object
#  504  DP03_0115PE   object
#  505  DP03_0115PM   object
#  506  DP03_0116PE   object
#  507  DP03_0116PM   object
#  508  DP03_0117PE   object
#  509  DP03_0117PM   object
#  510  DP03_0118PE   object
#  511  DP03_0118PM   object
#  512  DP03_0119PE   object
#  513  DP03_0119PM   object
#  514  DP03_0120PE   object
#  515  DP03_0120PM   object
#  516  DP03_0121PE   object
#  517  DP03_0121PM   object
#  518  DP03_0122PE   object
#  519  DP03_0122PM   object
#  520  DP03_0123PE   object
#  521  DP03_0123PM   object
#  522  DP03_0124PE   object
#  523  DP03_0124PM   object
#  524  DP03_0125PE   object
#  525  DP03_0125PM   object
#  526  DP03_0126PE   object
#  527  DP03_0126PM   object
#  528  DP03_0127PE   object
#  529  DP03_0127PM   object
#  530  DP03_0128PE   object
#  531  DP03_0128PM   object
#  532  DP03_0129PE   object
#  533  DP03_0129PM   object
#  534  DP03_0130PE   object
#  535  DP03_0130PM   object
#  536  DP03_0131PE   object
#  537  DP03_0131PM   object
#  538  DP03_0132PE   object
#  539  DP03_0132PM   object
#  540  DP03_0133PE   object
#  541  DP03_0133PM   object
#  542  DP03_0134PE   object
#  543  DP03_0134PM   object
#  544  DP03_0135PE   object
#  545  DP03_0135PM   object
#  546  DP03_0136PE   object
#  547  DP03_0136PM   object
#  548  DP03_0137PE   object
#  549  DP03_0137PM   object
#  550  Unnamed: 550  float64
# dtypes: float64(1), object(550)
# memory usage: 185.2+ KB

# %% [markdown]
# **Observation:** The `census_economic_df` DataFrame presents several challenges for the cleaning phase.
# 1.  **Missing Values:** The dataset contains no missing values.
# 2.  **Column Names:** The column names are cryptic codes and will need to be renamed using the provided metadata file.
# 3.  **Data Types:** Most columns are incorrectly typed as `object` and will need to be converted to numeric types for analysis.

# %% [markdown]
# ## 5. Initial Data Cleaning

# %% [markdown]
# ### 5.1 Clean CDC Health Data

# %%
# List out current columns in CDC dataframe
cdc_health_df.columns
# Out:
# Index(['Year', 'StateAbbr', 'StateDesc', 'LocationName', 'DataSource',
#        'Category', 'Measure', 'Data_Value_Unit', 'Data_Value_Type',
#        'Data_Value', 'Data_Value_Footnote_Symbol', 'Data_Value_Footnote',
#        'Low_Confidence_Limit', 'High_Confidence_Limit', 'TotalPopulation',
#        'TotalPop18plus', 'LocationID', 'CategoryID', 'MeasureId',
#        'DataValueTypeID', 'Short_Question_Text', 'Geolocation'],
#       dtype='object')

# %%
# Create a list of the footnote columns to remove
columns_to_drop = [
    # Footnote columns
    'Data_Value_Footnote_Symbol',
    'Data_Value_Footnote',
    # Redundant ID columns
    'CategoryID',
    'MeasureId',
    'DataValueTypeID',
    # Redundant Measure description
    'Short_Question_Text',
    # Redundant geographic and source columns
    'StateAbbr',
    'StateDesc',
    'DataSource'
]

# Drop the columns
cdc_health_df_cleaned = cdc_health_df.drop(columns=columns_to_drop)

# Confirm the columns are gone
print("Unneeded columns removed successfully.")
cdc_health_df_cleaned.info()
# Out:
# Unneeded columns removed successfully.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4640 entries, 0 to 4639
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Year                   4640 non-null   int64
#  1   LocationName           4640 non-null   object
#  2   Category               4640 non-null   object
#  3   Measure                4640 non-null   object
#  4   Data_Value_Unit        4640 non-null   object
#  5   Data_Value_Type        4640 non-null   object
#  6   Data_Value             4640 non-null   float64
#  7   Low_Confidence_Limit   4640 non-null   float64
#  8   High_Confidence_Limit  4640 non-null   float64
#  9   TotalPopulation        4640 non-null   object
#  10  TotalPop18plus         4640 non-null   object
#  11  LocationID             4640 non-null   int64
#  12  Geolocation            4640 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 471.4+ KB

# %%
# Count the number of duplicated rows
duplicate_count = cdc_health_df_cleaned.duplicated().sum()

print(f"Found {duplicate_count} duplicate rows.")
# Out:
# Found 0 duplicate rows.

# %%
# Create a dictionary to map old names to new, snake_case names
column_rename_map = {
    'Year': 'year',
    'LocationName': 'county',
    'Category': 'category',
    'Measure': 'measure',
    'Data_Value_Unit': 'data_unit',
    'Data_Value_Type': 'data_type',
    'Data_Value': 'value',
    'Low_Confidence_Limit': 'low_confidence_limit',
    'High_Confidence_Limit': 'high_confidence_limit',
    'TotalPopulation': 'total_population',
    'TotalPop18plus': 'population_18_plus',
    'LocationID': 'location_id',
    'Geolocation': 'geolocation'
}

# Apply the renaming
cdc_health_df_cleaned = cdc_health_df_cleaned.rename(columns=column_rename_map)

# Remove commas and convert population columns to numeric integers
cdc_health_df_cleaned['total_population'] = cdc_health_df_cleaned['total_population'].str.replace(',', '').astype(int)
cdc_health_df_cleaned['population_18_plus'] = cdc_health_df_cleaned['population_18_plus'].str.replace(',', '').astype(int)

# Check for duplicates
duplicate_count = cdc_health_df_cleaned.duplicated().sum()
print(f"Found {duplicate_count} duplicate rows.")

# Final check to confirm all changes
print("\nCDC data cleaned, renamed, and types corrected.")
cdc_health_df_cleaned.info()
# Out:
# Found 0 duplicate rows.
#
# CDC data cleaned, renamed, and types corrected.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4640 entries, 0 to 4639
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   year                   4640 non-null   int64
#  1   county                 4640 non-null   object
#  2   category               4640 non-null   object
#  3   measure                4640 non-null   object
#  4   data_unit              4640 non-null   object
#  5   data_type              4640 non-null   object
#  6   value                  4640 non-null   float64
#  7   low_confidence_limit   4640 non-null   float64
#  8   high_confidence_limit  4640 non-null   float64
#  9   total_population       4640 non-null   int64
#  10  population_18_plus     4640 non-null   int64
#  11  location_id            4640 non-null   int64
#  12  geolocation            4640 non-null   object
# dtypes: float64(3), int64(4), object(6)
# memory usage: 471.4+ KB

# %% [markdown]
# ### 5.2 Clean EPA Air Quality Data

# %%
# Display the original number of rows for comparison
print(f"Original number of rows (USA-wide): {len(epa_aqi_df)}")

# Filter the DataFrame to only include rows where the 'State' is 'California'
# Using .copy() is important to ensure our new DataFrame is independent
epa_aqi_df_cleaned = epa_aqi_df[epa_aqi_df['State'] == 'California'].copy()

# Display the new number of rows
print(f"New number of rows (California only): {len(epa_aqi_df_cleaned)}")

# Display the first few rows of the new, filtered DataFrame to confirm
epa_aqi_df_cleaned.head()
# Out:
# Original number of rows (USA-wide): 995
# New number of rows (California only): 52
#          State     County  Year  Days with AQI  Good Days  Moderate Days  \
# 47  California    Alameda  2024             61         52              9
# 48  California     Amador  2024            359        281             72
# 49  California      Butte  2024            366        231            133
# 50  California  Calaveras  2024            359        261             90
# 51  California     Colusa  2024            366         68            298
#
#     Unhealthy for Sensitive Groups Days  Unhealthy Days  Very Unhealthy Days  \
# 47                                    0               0                    0
# 48                                    6               0                    0
# 49                                    0               1                    1
# 50                                    8               0                    0
# 51                                    0               0                    0
#
#     Hazardous Days  Max AQI  90th Percentile AQI  Median AQI  Days CO  \
# 47               0       63                   55          39        1
# 48               0      143                   74          40        0
# 49               0      213                   71          46        0
# 50               0      129                   74          42        0
# 51               0       90                   63          54        0
#
#     Days NO2  Days Ozone  Days PM2.5  Days PM10
# 47         2          18          40          0
# 48         0         359           0          0
# 49         0         243         115          8
# 50         0         273          86          0
# 51         0          31         331          4

# %%
#Filter dataframe for California
epa_aqi_df_cleaned = epa_aqi_df[epa_aqi_df['State'] == 'California'].copy()

# Create a dictionary to rename the columns to snake_case
column_rename_map = {
    'State': 'state',
    'County': 'county',
    'Year': 'year',
    'Days with AQI': 'days_with_aqi',
    'Good Days': 'good_days',
    'Moderate Days': 'moderate_days',
    'Unhealthy for Sensitive Groups Days': 'unhealthy_sensitive_days',
    'Unhealthy Days': 'unhealthy_days',
    'Very Unhealthy Days': 'very_unhealthy_days',
    'Hazardous Days': 'hazardous_days',
    'Max AQI': 'max_aqi',
    '90th Percentile AQI': 'percentile_90th_aqi',
    'Median AQI': 'median_aqi',
    'Days CO': 'days_co',
    'Days NO2': 'days_no2',
    'Days Ozone': 'days_ozone',
    'Days SO2': 'days_so2',
    'Days PM2.5': 'days_pm2_5',
    'Days PM10': 'days_pm10'
}

# Apply the renaming
epa_aqi_df_cleaned = epa_aqi_df_cleaned.rename(columns=column_rename_map)

# Drop the redundant 'state' and 'year' columns
epa_aqi_df_cleaned.drop(columns=['state', 'year'], inplace=True, errors='ignore')

# Check for duplicate rows
duplicate_count = epa_aqi_df_cleaned.duplicated().sum()
print(f"Found {duplicate_count} duplicate rows.")

# Display the final, cleaned DataFrame's info and head
print("\nEPA AQI data cleaned successfully.")
epa_aqi_df_cleaned.info()
# Out:
# Found 0 duplicate rows.
#
# EPA AQI data cleaned successfully.
# <class 'pandas.core.frame.DataFrame'>
# Index: 52 entries, 47 to 98
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   county                    52 non-null     object
#  1   days_with_aqi             52 non-null     int64
#  2   good_days                 52 non-null     int64
#  3   moderate_days             52 non-null     int64
#  4   unhealthy_sensitive_days  52 non-null     int64
#  5   unhealthy_days            52 non-null     int64
#  6   very_unhealthy_days       52 non-null     int64
#  7   hazardous_days            52 non-null     int64
#  8   max_aqi                   52 non-null     int64
#  9   percentile_90th_aqi       52 non-null     int64
#  10  median_aqi                52 non-null     int64
#  11  days_co                   52 non-null     int64
#  12  days_no2                  52 non-null     int64
#  13  days_ozone                52 non-null     int64
#  14  days_pm2_5                52 non-null     int64
#  15  days_pm10                 52 non-null     int64
# dtypes: int64(15), object(1)
# memory usage: 6.9+ KB

# %% [markdown]
# ### 5.3 Clean Census Economic Data

# %%
# List out title row in Census Dataframe
census_economic_df.head(1)
# Out:
#       GEO_ID                  NAME  \
# 0  Geography  Geographic Area Name
#
#                                           DP03_0001E  \
# 0  Estimate!!EMPLOYMENT STATUS!!Population 16 yea...
#
#                                           DP03_0001M  \
# 0  Margin of Error!!EMPLOYMENT STATUS!!Population...
#
#                                           DP03_0002E  \
# 0  Estimate!!EMPLOYMENT STATUS!!Population 16 yea...
#
#                                           DP03_0002M  \
# 0  Margin of Error!!EMPLOYMENT STATUS!!Population...
#
#                                           DP03_0003E  \
# 0  Estimate!!EMPLOYMENT STATUS!!Population 16 yea...
#
#                                           DP03_0003M  \
# 0  Margin of Error!!EMPLOYMENT STATUS!!Population...
#
#                                           DP03_0004E  \
# 0  Estimate!!EMPLOYMENT STATUS!!Population 16 yea...
#
#                                           DP03_0004M  ...  \
# 0  Margin of Error!!EMPLOYMENT STATUS!!Population...  ...
#
#                                          DP03_0133PM  \
# 0  Percent Margin of Error!!PERCENTAGE OF FAMILIE...
#
#                                          DP03_0134PE  \
# 0  Percent!!PERCENTAGE OF FAMILIES AND PEOPLE WHO...
#
#                                          DP03_0134PM  \
# 0  Percent Margin of Error!!PERCENTAGE OF FAMILIE...
#
#                                          DP03_0135PE  \
# 0  Percent!!PERCENTAGE OF FAMILIES AND PEOPLE WHO...
#
#                                          DP03_0135PM  \
# 0  Percent Margin of Error!!PERCENTAGE OF FAMILIE...
#
#                                          DP03_0136PE  \
# 0  Percent!!PERCENTAGE OF FAMILIES AND PEOPLE WHO...
#
#                                          DP03_0136PM  \
# 0  Percent Margin of Error!!PERCENTAGE OF FAMILIE...
#
#                                          DP03_0137PE  \
# 0  Percent!!PERCENTAGE OF FAMILIES AND PEOPLE WHO...
#
#                                          DP03_0137PM Unnamed: 550
# 0  Percent Margin of Error!!PERCENTAGE OF FAMILIE...          NaN
#
# [1 rows x 551 columns]

# %%
# Create a new DataFrame to work on, preserving the original
temp_df = census_economic_df.copy()

# Promote the first row to be the header
temp_df.columns = temp_df.iloc[0]

# Drop the old header row (index 0)
temp_df = temp_df.drop(0)

# Create a new list of  snake_case column names
cleaned_columns = []
for col in temp_df.columns:
    # Convert the column name to a string
    clean_col = str(col)
    # Replace the '!!' separator and spaces with underscores, then convert to lowercase
    clean_col = clean_col.replace('!!', '_').replace(' ', '_').lower()
    cleaned_columns.append(clean_col)

# Assign the new, clean list as the column headers
temp_df.columns = cleaned_columns

# Rename the first column, which contains the county name, to be consistent
temp_df = temp_df.rename(columns={'geographic_area_name': 'county'})

#Drop nan column
temp_df.drop(columns=['nan'], inplace=True, errors='ignore')

# Clean the county names (e.g., "Alameda County, California" -> "Alameda")
temp_df['county'] = temp_df['county'].str.replace(' County, California', '')

# Reset the index and assign to the final cleaned DataFrame
census_economic_df_cleaned = temp_df.reset_index(drop=True)

# Create a list of all columns to be converted to a numeric type
columns_to_convert = census_economic_df_cleaned.columns.drop(['county', 'geography'])

# Loop through each column in the list
for column in columns_to_convert:
    # Convert the column to a numeric type.
    # The `errors='coerce'` will turn any non-numeric value into NaN (Not a Number)
    census_economic_df_cleaned[column] = pd.to_numeric(census_economic_df_cleaned[column], errors='coerce')

# Ensure the 'geography' ID column is treated as a string/object, not a number
census_economic_df_cleaned['geography'] = census_economic_df_cleaned['geography'].astype(str)

# List of the specific columns for analysis
columns_to_keep = [
    # --- Identifiers ---
    'county',
    'geography',

    # --- Income & Poverty ---
    # The overall poverty rate for all people in the county.
    'percent_percentage_of_families_and_people_whose_income_in_the_past_12_months_is_below_the_poverty_level_all_people',
    # A direct measure of economic resources, per person.
    'estimate_income_and_benefits_(in_2024_inflation-adjusted_dollars)_per_capita_income_(dollars)',

    # --- Employment ---
    # The standard unemployment rate.
    'percent_employment_status_civilian_labor_force_unemployment_rate',

    # --- Health Insurance ---
    # A direct measure of healthcare access vulnerability.
    'percent_health_insurance_coverage_civilian_noninstitutionalized_population_no_health_insurance_coverage'
]

# Create the final, lean DataFrame containing only the selected columns
census_economic_df_final = census_economic_df_cleaned[columns_to_keep].copy()

# Create a dictionary to map the long names to short ones
final_rename_map = {
    'percent_percentage_of_families_and_people_whose_income_in_the_past_12_months_is_below_the_poverty_level_all_people': 'poverty_rate',
    'estimate_income_and_benefits_(in_2024_inflation-adjusted_dollars)_per_capita_income_(dollars)': 'per_capita_income',
    'percent_employment_status_civilian_labor_force_unemployment_rate': 'unemployment_rate',
    'percent_health_insurance_coverage_civilian_noninstitutionalized_population_no_health_insurance_coverage': 'no_health_insurance_rate'
}

# Apply the final renaming
census_economic_df_final = census_economic_df_final.rename(columns=final_rename_map)

# Confirm your final, polished DataFrame
# Confirm your final DataFrame is ready for analysis
print("Final census DataFrame cleaned successfully with selected features.")
census_economic_df_final.head()
# Out:
# Final census DataFrame cleaned successfully with selected features.
#          county       geography  poverty_rate  per_capita_income  \
# 0       Alameda  0500000US06001           8.7              65740
# 1         Butte  0500000US06007          19.5              36028
# 2  Contra Costa  0500000US06013           8.4              63465
# 3     El Dorado  0500000US06017           7.8              61301
# 4        Fresno  0500000US06019          18.3              32282
#
#    unemployment_rate  no_health_insurance_rate
# 0                4.9                       3.8
# 1                7.6                       6.2
# 2                7.6                       4.3
# 3                2.8                       4.0
# 4                8.7                       6.0

# %% [markdown]
# ## 6. Data Merging

# %% [markdown]
# ### 6.1 Validate Merge Keys

# %%
# Verify the CDC dataset against the known number of CA counties (58).
cdc_county_count = len(cdc_health_df_cleaned['county'].unique())
print(f"Number of unique counties in CDC data: {cdc_county_count}")

if cdc_county_count == 58:
    print("Validation successful: The CDC dataset contains all 58 California counties.")
else:
    print(f"Warning: The CDC dataset has {cdc_county_count} counties, not the expected 58.")

# Verify data types of the 'county' column
print("\n--- Merge Key Data Type Check ---")

# Get the data type of the county column from each DataFrame
cdc_type = cdc_health_df_cleaned['county'].dtype
epa_type = epa_aqi_df_cleaned['county'].dtype
census_type = census_economic_df_final['county'].dtype

# Check if all three types are identical
is_consistent = (cdc_type == epa_type == census_type)

# Check if that consistent type is 'object' (a string)
is_correct_type = (cdc_type == 'object')

if is_consistent and is_correct_type:
    print("Validation successful: All 'county' columns are 'object' type.")

else:
    print("Validation FAILED: Data types are inconsistent or incorrect.")
    print(f"  CDC data 'county' type: {cdc_type}")
    print(f"  EPA data 'county' type: {epa_type}")
    print(f"  Census data 'county' type: {census_type}")
# Out:
# Number of unique counties in CDC data: 58
# Validation successful: The CDC dataset contains all 58 California counties.
#
# --- Merge Key Data Type Check ---
# Validation successful: All 'county' columns are 'object' type.

# %% [markdown]
# ### 6.2 Identify Merge Inconsistencies

# %%
# Convert the lists of unique counties into sets for comparison
cdc_counties = set(cdc_health_df_cleaned['county'].unique())
epa_counties = set(epa_aqi_df_cleaned['county'].unique())
census_counties = set(census_economic_df_final['county'].unique())

# Find all unique county names
all_counties = sorted(list(cdc_counties.union(epa_counties, census_counties)))

# Create a comparison DataFrame to find inconsistencies
comparison_df = pd.DataFrame({'county': all_counties})
comparison_df['in_cdc'] = comparison_df['county'].isin(cdc_counties)
comparison_df['in_epa'] = comparison_df['county'].isin(epa_counties)
comparison_df['in_census'] = comparison_df['county'].isin(census_counties)
inconsistent_counties = comparison_df[~(comparison_df['in_cdc'] & comparison_df['in_epa'] & comparison_df['in_census'])]

# Get a list of counties that will be excluded by the inner merge
excluded_counties = inconsistent_counties['county'].tolist()

print("The following counties will be excluded during the inner merge due to incomplete data:")
print(excluded_counties)
# Out:
# The following counties will be excluded during the inner merge due to incomplete data:
# ['Alpine', 'Amador', 'Calaveras', 'Colusa', 'Del Norte', 'Glenn', 'Inyo', 'Lassen', 'Mariposa', 'Modoc', 'Mono', 'Napa', 'Plumas', 'Sierra', 'Siskiyou', 'Trinity', 'Tuolumne', 'Yuba']

# %% [markdown]
# ### 6.3 Document Findings and Perform Merge

# %% [markdown]
# **Finding: Data Availability Across Sources**
#
# A comparison of the county lists from the three datasets revealed:
# 1.  **Inconsistency:** The EPA and Census datasets are missing many smaller, less populated counties that are present in the comprehensive CDC health dataset.
# 2.  **Action:** To ensure the final dataset is complete, an inner merge will be performed.
# 3.  **Limitation:** This defines the scope of the final analysis to the 42 counties for which complete data is available across all three sources. All subsequent findings and the final EQI will be based on this specific set of counties.

# %%
# Merge the three DataFrames using an 'inner' join on the 'county' column

# Merge the first two DataFrames: census and epa
merged_df = pd.merge(
    left=census_economic_df_final,
    right=epa_aqi_df_cleaned,
    how='inner',
    on='county'
)

# Merge the result with the final DataFrame: cdc
master_df = pd.merge(
    left=merged_df,
    right=cdc_health_df_cleaned,
    how='inner',
    on='county'
)

# Confirm the final merged DataFrame's shape and content
print(f"Final merged DataFrame shape: {master_df.shape}")
master_df.info()
# Out:
# Final merged DataFrame shape: (3200, 33)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3200 entries, 0 to 3199
# Data columns (total 33 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   county                    3200 non-null   object
#  1   geography                 3200 non-null   object
#  2   poverty_rate              3200 non-null   float64
#  3   per_capita_income         3200 non-null   int64
#  4   unemployment_rate         3200 non-null   float64
#  5   no_health_insurance_rate  3200 non-null   float64
#  6   days_with_aqi             3200 non-null   int64
#  7   good_days                 3200 non-null   int64
#  8   moderate_days             3200 non-null   int64
#  9   unhealthy_sensitive_days  3200 non-null   int64
#  10  unhealthy_days            3200 non-null   int64
#  11  very_unhealthy_days       3200 non-null   int64
#  12  hazardous_days            3200 non-null   int64
#  13  max_aqi                   3200 non-null   int64
#  14  percentile_90th_aqi       3200 non-null   int64
#  15  median_aqi                3200 non-null   int64
#  16  days_co                   3200 non-null   int64
#  17  days_no2                  3200 non-null   int64
#  18  days_ozone                3200 non-null   int64
#  19  days_pm2_5                3200 non-null   int64
#  20  days_pm10                 3200 non-null   int64
#  21  year                      3200 non-null   int64
#  22  category                  3200 non-null   object
#  23  measure                   3200 non-null   object
#  24  data_unit                 3200 non-null   object
#  25  data_type                 3200 non-null   object
#  26  value                     3200 non-null   float64
#  27  low_confidence_limit      3200 non-null   float64
#  28  high_confidence_limit     3200 non-null   float64
#  29  total_population          3200 non-null   int64
#  30  population_18_plus        3200 non-null   int64
#  31  location_id               3200 non-null   int64
#  32  geolocation               3200 non-null   object
# dtypes: float64(6), int64(20), object(7)
# memory usage: 825.1+ KB

# %% [markdown]
# ### 6.4 Filter Health Measures

# %%
# Check the different data types available from the CDC health data
print(f"Available data types: {master_df['data_type'].unique()}")

# Filter to keep only the 'Age-adjusted prevalence' data from the CDC measures.
# This ensures a fair comparison across counties with different age structures.
master_df_filtered = master_df[master_df['data_type'] == 'Age-adjusted prevalence'].copy()

# Confirm the row count is now smaller
print(f"Original row count: {len(master_df)}")
print(f"New filtered row count: {len(master_df_filtered)}")
# Out:
# Available data types: ['Crude prevalence' 'Age-adjusted prevalence']
# Original row count: 3200
# New filtered row count: 1600

# %% [markdown]
# ### 6.5 Pivot Data to Wide Format

# %%
# Create a minimal list of index columns, unique per county
# These are only the columns from Census and EPA data.
id_columns = [
    'county', 'geography', 'poverty_rate', 'per_capita_income',
    'unemployment_rate', 'no_health_insurance_rate', 'days_with_aqi',
    'good_days', 'moderate_days', 'unhealthy_sensitive_days',
    'unhealthy_days', 'very_unhealthy_days', 'hazardous_days',
    'max_aqi', 'percentile_90th_aqi', 'median_aqi', 'days_co',
    'days_no2', 'days_ozone', 'days_pm2_5', 'days_pm10'
]

# Pivot the filtered table using the minimal index
master_wide_df = master_df_filtered.pivot_table(
    index=id_columns,
    columns='measure',
    values='value'
).reset_index()

# Clean up the column names
master_wide_df.columns.name = None

# Confirm the new "wide" DataFrame
print("DataFrame pivoted successfully.")
master_wide_df.info()
# Out:
# DataFrame pivoted successfully.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 61 columns):
#  #   Column                                                                                Non-Null Count  Dtype
# ---  ------                                                                                --------------  -----
#  0   county                                                                                40 non-null     object
#  1   geography                                                                             40 non-null     object
#  2   poverty_rate                                                                          40 non-null     float64
#  3   per_capita_income                                                                     40 non-null     int64
#  4   unemployment_rate                                                                     40 non-null     float64
#  5   no_health_insurance_rate                                                              40 non-null     float64
#  6   days_with_aqi                                                                         40 non-null     int64
#  7   good_days                                                                             40 non-null     int64
#  8   moderate_days                                                                         40 non-null     int64
#  9   unhealthy_sensitive_days                                                              40 non-null     int64
#  10  unhealthy_days                                                                        40 non-null     int64
#  11  very_unhealthy_days                                                                   40 non-null     int64
#  12  hazardous_days                                                                        40 non-null     int64
#  13  max_aqi                                                                               40 non-null     int64
#  14  percentile_90th_aqi                                                                   40 non-null     int64
#  15  median_aqi                                                                            40 non-null     int64
#  16  days_co                                                                               40 non-null     int64
#  17  days_no2                                                                              40 non-null     int64
#  18  days_ozone                                                                            40 non-null     int64
#  19  days_pm2_5                                                                            40 non-null     int64
#  20  days_pm10                                                                             40 non-null     int64
#  21  All teeth lost among adults aged >=65 years                                           40 non-null     float64
#  22  Any disability among adults                                                           40 non-null     float64
#  23  Arthritis among adults                                                                40 non-null     float64
#  24  Binge drinking among adults                                                           40 non-null     float64
#  25  Cancer (non-skin) or melanoma among adults                                            40 non-null     float64
#  26  Cholesterol screening among adults                                                    40 non-null     float64
#  27  Chronic obstructive pulmonary disease among adults                                    40 non-null     float64
#  28  Cognitive disability among adults                                                     40 non-null     float64
#  29  Colorectal cancer screening among adults aged 45–75 years                             40 non-null     float64
#  30  Coronary heart disease among adults                                                   40 non-null     float64
#  31  Current asthma among adults                                                           40 non-null     float64
#  32  Current cigarette smoking among adults                                                40 non-null     float64
#  33  Current lack of health insurance among adults aged 18-64 years                        40 non-null     float64
#  34  Depression among adults                                                               40 non-null     float64
#  35  Diagnosed diabetes among adults                                                       40 non-null     float64
#  36  Fair or poor self-rated health status among adults                                    40 non-null     float64
#  37  Feeling socially isolated among adults                                                40 non-null     float64
#  38  Food insecurity in the past 12 months among adults                                    40 non-null     float64
#  39  Frequent mental distress among adults                                                 40 non-null     float64
#  40  Frequent physical distress among adults                                               40 non-null     float64
#  41  Hearing disability among adults                                                       40 non-null     float64
#  42  High blood pressure among adults                                                      40 non-null     float64
#  43  High cholesterol among adults who have ever been screened                             40 non-null     float64
#  44  Housing insecurity in the past 12 months among adults                                 40 non-null     float64
#  45  Independent living disability among adults                                            40 non-null     float64
#  46  Lack of reliable transportation in the past 12 months among adults                    40 non-null     float64
#  47  Lack of social and emotional support among adults                                     40 non-null     float64
#  48  Mammography use among women aged 50-74 years                                          40 non-null     float64
#  49  Mobility disability among adults                                                      40 non-null     float64
#  50  No leisure-time physical activity among adults                                        40 non-null     float64
#  51  Obesity among adults                                                                  40 non-null     float64
#  52  Received food stamps in the past 12 months among adults                               40 non-null     float64
#  53  Self-care disability among adults                                                     40 non-null     float64
#  54  Short sleep duration among adults                                                     40 non-null     float64
#  55  Stroke among adults                                                                   40 non-null     float64
#  56  Taking medicine to control high blood pressure among adults with high blood pressure  40 non-null     float64
#  57  Utility services shut-off threat in the past 12 months among adults                   40 non-null     float64
#  58  Vision disability among adults                                                        40 non-null     float64
#  59  Visited dentist or dental clinic in the past year among adults                        40 non-null     float64
#  60  Visits to doctor for routine checkup within the past year among adults                40 non-null     float64
# dtypes: float64(43), int64(16), object(2)
# memory usage: 19.2+ KB

# %% [markdown]
# ### 6.6 Clean Final Column Names

# %%
# Copy master df
master_df_final = master_wide_df.copy()

# Clean all column names to be lowercase, snake_case
master_df_final.columns = master_df_final.columns.str.lower()
master_df_final.columns = master_df_final.columns.str.replace(' ', '_', regex=False)
master_df_final.columns = master_df_final.columns.str.replace('[^a-z0-9_]', '', regex=True)

# Confirm the final, fully-prepared DataFrame
print("\nFinal column names cleaned.")
master_df_final.info()
# Out:
# Final column names cleaned.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 61 columns):
#  #   Column                                                                                Non-Null Count  Dtype
# ---  ------                                                                                --------------  -----
#  0   county                                                                                40 non-null     object
#  1   geography                                                                             40 non-null     object
#  2   poverty_rate                                                                          40 non-null     float64
#  3   per_capita_income                                                                     40 non-null     int64
#  4   unemployment_rate                                                                     40 non-null     float64
#  5   no_health_insurance_rate                                                              40 non-null     float64
#  6   days_with_aqi                                                                         40 non-null     int64
#  7   good_days                                                                             40 non-null     int64
#  8   moderate_days                                                                         40 non-null     int64
#  9   unhealthy_sensitive_days                                                              40 non-null     int64
#  10  unhealthy_days                                                                        40 non-null     int64
#  11  very_unhealthy_days                                                                   40 non-null     int64
#  12  hazardous_days                                                                        40 non-null     int64
#  13  max_aqi                                                                               40 non-null     int64
#  14  percentile_90th_aqi                                                                   40 non-null     int64
#  15  median_aqi                                                                            40 non-null     int64
#  16  days_co                                                                               40 non-null     int64
#  17  days_no2                                                                              40 non-null     int64
#  18  days_ozone                                                                            40 non-null     int64
#  19  days_pm2_5                                                                            40 non-null     int64
#  20  days_pm10                                                                             40 non-null     int64
#  21  all_teeth_lost_among_adults_aged_65_years                                             40 non-null     float64
#  22  any_disability_among_adults                                                           40 non-null     float64
#  23  arthritis_among_adults                                                                40 non-null     float64
#  24  binge_drinking_among_adults                                                           40 non-null     float64
#  25  cancer_nonskin_or_melanoma_among_adults                                               40 non-null     float64
#  26  cholesterol_screening_among_adults                                                    40 non-null     float64
#  27  chronic_obstructive_pulmonary_disease_among_adults                                    40 non-null     float64
#  28  cognitive_disability_among_adults                                                     40 non-null     float64
#  29  colorectal_cancer_screening_among_adults_aged_4575_years                              40 non-null     float64
#  30  coronary_heart_disease_among_adults                                                   40 non-null     float64
#  31  current_asthma_among_adults                                                           40 non-null     float64
#  32  current_cigarette_smoking_among_adults                                                40 non-null     float64
#  33  current_lack_of_health_insurance_among_adults_aged_1864_years                         40 non-null     float64
#  34  depression_among_adults                                                               40 non-null     float64
#  35  diagnosed_diabetes_among_adults                                                       40 non-null     float64
#  36  fair_or_poor_selfrated_health_status_among_adults                                     40 non-null     float64
#  37  feeling_socially_isolated_among_adults                                                40 non-null     float64
#  38  food_insecurity_in_the_past_12_months_among_adults                                    40 non-null     float64
#  39  frequent_mental_distress_among_adults                                                 40 non-null     float64
#  40  frequent_physical_distress_among_adults                                               40 non-null     float64
#  41  hearing_disability_among_adults                                                       40 non-null     float64
#  42  high_blood_pressure_among_adults                                                      40 non-null     float64
#  43  high_cholesterol_among_adults_who_have_ever_been_screened                             40 non-null     float64
#  44  housing_insecurity_in_the_past_12_months_among_adults                                 40 non-null     float64
#  45  independent_living_disability_among_adults                                            40 non-null     float64
#  46  lack_of_reliable_transportation_in_the_past_12_months_among_adults                    40 non-null     float64
#  47  lack_of_social_and_emotional_support_among_adults                                     40 non-null     float64
#  48  mammography_use_among_women_aged_5074_years                                           40 non-null     float64
#  49  mobility_disability_among_adults                                                      40 non-null     float64
#  50  no_leisuretime_physical_activity_among_adults                                         40 non-null     float64
#  51  obesity_among_adults                                                                  40 non-null     float64
#  52  received_food_stamps_in_the_past_12_months_among_adults                               40 non-null     float64
#  53  selfcare_disability_among_adults                                                      40 non-null     float64
#  54  short_sleep_duration_among_adults                                                     40 non-null     float64
#  55  stroke_among_adults                                                                   40 non-null     float64
#  56  taking_medicine_to_control_high_blood_pressure_among_adults_with_high_blood_pressure  40 non-null     float64
#  57  utility_services_shutoff_threat_in_the_past_12_months_among_adults                    40 non-null     float64
#  58  vision_disability_among_adults                                                        40 non-null     float64
#  59  visited_dentist_or_dental_clinic_in_the_past_year_among_adults                        40 non-null     float64
#  60  visits_to_doctor_for_routine_checkup_within_the_past_year_among_adults                40 non-null     float64
# dtypes: float64(43), int64(16), object(2)
# memory usage: 19.2+ KB

# %% [markdown]
# ## 7. Prepare Data for PCA

# %% [markdown]
# ### 7.1 Select Features for PCA

# %%
# Define columns to exclude from the PCA calculation
# (identifiers, metadata, and any features you choose to omit)
exclude_from_pca = [
    'county',
    'geography',
    'year',           # Metadata
    'location_id',    # Metadata
    'geolocation',    # Metadata
    # Redundant AQI day counts
    'days_with_aqi',
    'good_days', 'moderate_days', 'unhealthy_sensitive_days',
    'unhealthy_days', 'very_unhealthy_days', 'hazardous_days'
]

# Create the DataFrame specifically for PCA input
# Select only numeric types and drop the excluded columns
pca_input_df = master_df_final.select_dtypes(include=['float64', 'int64'])
pca_input_df = pca_input_df.drop(columns=exclude_from_pca, errors='ignore')

print("Selected data for PCA:")
pca_input_df.info()
# Out:
# Selected data for PCA:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 52 columns):
#  #   Column                                                                                Non-Null Count  Dtype
# ---  ------                                                                                --------------  -----
#  0   poverty_rate                                                                          40 non-null     float64
#  1   per_capita_income                                                                     40 non-null     int64
#  2   unemployment_rate                                                                     40 non-null     float64
#  3   no_health_insurance_rate                                                              40 non-null     float64
#  4   max_aqi                                                                               40 non-null     int64
#  5   percentile_90th_aqi                                                                   40 non-null     int64
#  6   median_aqi                                                                            40 non-null     int64
#  7   days_co                                                                               40 non-null     int64
#  8   days_no2                                                                              40 non-null     int64
#  9   days_ozone                                                                            40 non-null     int64
#  10  days_pm2_5                                                                            40 non-null     int64
#  11  days_pm10                                                                             40 non-null     int64
#  12  all_teeth_lost_among_adults_aged_65_years                                             40 non-null     float64
#  13  any_disability_among_adults                                                           40 non-null     float64
#  14  arthritis_among_adults                                                                40 non-null     float64
#  15  binge_drinking_among_adults                                                           40 non-null     float64
#  16  cancer_nonskin_or_melanoma_among_adults                                               40 non-null     float64
#  17  cholesterol_screening_among_adults                                                    40 non-null     float64
#  18  chronic_obstructive_pulmonary_disease_among_adults                                    40 non-null     float64
#  19  cognitive_disability_among_adults                                                     40 non-null     float64
#  20  colorectal_cancer_screening_among_adults_aged_4575_years                              40 non-null     float64
#  21  coronary_heart_disease_among_adults                                                   40 non-null     float64
#  22  current_asthma_among_adults                                                           40 non-null     float64
#  23  current_cigarette_smoking_among_adults                                                40 non-null     float64
#  24  current_lack_of_health_insurance_among_adults_aged_1864_years                         40 non-null     float64
#  25  depression_among_adults                                                               40 non-null     float64
#  26  diagnosed_diabetes_among_adults                                                       40 non-null     float64
#  27  fair_or_poor_selfrated_health_status_among_adults                                     40 non-null     float64
#  28  feeling_socially_isolated_among_adults                                                40 non-null     float64
#  29  food_insecurity_in_the_past_12_months_among_adults                                    40 non-null     float64
#  30  frequent_mental_distress_among_adults                                                 40 non-null     float64
#  31  frequent_physical_distress_among_adults                                               40 non-null     float64
#  32  hearing_disability_among_adults                                                       40 non-null     float64
#  33  high_blood_pressure_among_adults                                                      40 non-null     float64
#  34  high_cholesterol_among_adults_who_have_ever_been_screened                             40 non-null     float64
#  35  housing_insecurity_in_the_past_12_months_among_adults                                 40 non-null     float64
#  36  independent_living_disability_among_adults                                            40 non-null     float64
#  37  lack_of_reliable_transportation_in_the_past_12_months_among_adults                    40 non-null     float64
#  38  lack_of_social_and_emotional_support_among_adults                                     40 non-null     float64
#  39  mammography_use_among_women_aged_5074_years                                           40 non-null     float64
#  40  mobility_disability_among_adults                                                      40 non-null     float64
#  41  no_leisuretime_physical_activity_among_adults                                         40 non-null     float64
#  42  obesity_among_adults                                                                  40 non-null     float64
#  43  received_food_stamps_in_the_past_12_months_among_adults                               40 non-null     float64
#  44  selfcare_disability_among_adults                                                      40 non-null     float64
#  45  short_sleep_duration_among_adults                                                     40 non-null     float64
#  46  stroke_among_adults                                                                   40 non-null     float64
#  47  taking_medicine_to_control_high_blood_pressure_among_adults_with_high_blood_pressure  40 non-null     float64
#  48  utility_services_shutoff_threat_in_the_past_12_months_among_adults                    40 non-null     float64
#  49  vision_disability_among_adults                                                        40 non-null     float64
#  50  visited_dentist_or_dental_clinic_in_the_past_year_among_adults                        40 non-null     float64
#  51  visits_to_doctor_for_routine_checkup_within_the_past_year_among_adults                40 non-null     float64
# dtypes: float64(43), int64(9)
# memory usage: 16.4 KB

# %% [markdown]
# ### 7.2 Standardize Data

# %%
# Initialize the StandardScaler
scaler = StandardScaler()

# Fit the scaler to the PCA data and transform it
pca_data_scaled = scaler.fit_transform(pca_input_df)

# Convert the scaled data back into a DataFrame (optional but good practice)
pca_df_scaled = pd.DataFrame(pca_data_scaled, columns=pca_input_df.columns, index=pca_input_df.index)

# Confirm the scaling by checking summary statistics
print("\nScaled data summary statistics:")
pca_df_scaled.describe()
# Out:
# Scaled data summary statistics:
#        poverty_rate  per_capita_income  unemployment_rate  \
# count  4.000000e+01       4.000000e+01       4.000000e+01
# mean  -3.108624e-16       1.554312e-16       1.887379e-16
# std    1.012739e+00       1.012739e+00       1.012739e+00
# min   -1.372799e+00      -1.301964e+00      -1.709064e+00
# 25%   -8.061756e-01      -7.112943e-01      -6.932259e-01
# 50%   -2.058917e-01      -2.483321e-01      -2.801927e-01
# 75%    1.106879e+00       5.286986e-01       5.012213e-01
# max    1.903517e+00       2.719844e+00       2.756159e+00
#
#        no_health_insurance_rate       max_aqi  percentile_90th_aqi  \
# count              4.000000e+01  4.000000e+01         4.000000e+01
# mean              -3.108624e-16  8.881784e-17         1.665335e-16
# std                1.012739e+00  1.012739e+00         1.012739e+00
# min               -1.848481e+00 -1.151980e+00        -1.413051e+00
# 25%               -8.773589e-01 -6.431597e-01        -7.129823e-01
# 50%               -4.018438e-02 -9.664894e-02        -2.168173e-01
# 75%                1.098373e+00  2.667941e-01         4.628608e-01
# max                1.768113e+00  4.824640e+00         2.773766e+00
#
#          median_aqi    days_co      days_no2    days_ozone  ...  \
# count  4.000000e+01  40.000000  4.000000e+01  4.000000e+01  ...
# mean   1.776357e-16   0.000000  1.110223e-17  7.216450e-17  ...
# std    1.012739e+00   1.012739  1.012739e+00  1.012739e+00  ...
# min   -2.517623e+00  -0.267261 -3.031795e-01 -1.880196e+00  ...
# 25%   -5.061202e-01  -0.267261 -3.031795e-01 -5.671564e-01  ...
# 50%   -5.190976e-02  -0.267261 -3.031795e-01  2.031237e-01  ...
# 75%    2.238608e-01  -0.267261 -3.031795e-01  5.101392e-01  ...
# max    2.413804e+00   5.077964  5.535833e+00  1.946533e+00  ...
#
#        obesity_among_adults  \
# count          4.000000e+01
# mean          -1.465494e-15
# std            1.012739e+00
# min           -2.476654e+00
# 25%           -4.720778e-01
# 50%            4.911213e-02
# 75%            7.557254e-01
# max            1.793094e+00
#
#        received_food_stamps_in_the_past_12_months_among_adults  \
# count                                       4.000000e+01
# mean                                        5.329071e-16
# std                                         1.012739e+00
# min                                        -1.636131e+00
# 25%                                        -7.375394e-01
# 50%                                        -2.995304e-02
# 75%                                         6.342231e-01
# max                                         2.496521e+00
#
#        selfcare_disability_among_adults  short_sleep_duration_among_adults  \
# count                      4.000000e+01                       4.000000e+01
# mean                       2.442491e-16                       2.414735e-15
# std                        1.012739e+00                       1.012739e+00
# min                       -1.619656e+00                      -2.528321e+00
# 25%                       -5.972047e-01                      -5.782861e-01
# 50%                       -1.789290e-01                       6.532135e-02
# 75%                        4.484844e-01                       6.320802e-01
# max                        2.470150e+00                       2.389993e+00
#
#        stroke_among_adults  \
# count         4.000000e+01
# mean         -1.332268e-16
# std           1.012739e+00
# min          -2.014447e+00
# 25%          -6.970975e-01
# 50%           7.135644e-02
# 75%           6.202521e-01
# max           1.937602e+00
#
#        taking_medicine_to_control_high_blood_pressure_among_adults_with_high_blood_pressure  \
# count                                       4.000000e+01
# mean                                       -3.963496e-15
# std                                         1.012739e+00
# min                                        -2.347251e+00
# 25%                                        -8.439794e-01
# 50%                                         1.009339e-01
# 75%                                         8.525696e-01
# max                                         1.604205e+00
#
#        utility_services_shutoff_threat_in_the_past_12_months_among_adults  \
# count                                       4.000000e+01
# mean                                        2.664535e-16
# std                                         1.012739e+00
# min                                        -1.873630e+00
# 25%                                        -7.095039e-01
# 50%                                         3.798726e-02
# 75%                                         6.139231e-01
# max                                         2.439762e+00
#
#        vision_disability_among_adults  \
# count                    4.000000e+01
# mean                    -1.110223e-16
# std                      1.012739e+00
# min                     -1.696595e+00
# 25%                     -7.124230e-01
# 50%                     -1.689250e-01
# 75%                      3.451947e-01
# max                      2.592632e+00
#
#        visited_dentist_or_dental_clinic_in_the_past_year_among_adults  \
# count                                       4.000000e+01
# mean                                       -9.992007e-16
# std                                         1.012739e+00
# min                                        -2.003804e+00
# 25%                                        -6.785923e-01
# 50%                                         8.287830e-02
# 75%                                         6.760681e-01
# max                                         2.287357e+00
#
#        visits_to_doctor_for_routine_checkup_within_the_past_year_among_adults
# count                                       4.000000e+01
# mean                                        2.775558e-16
# std                                         1.012739e+00
# min                                        -2.032705e+00
# 25%                                        -7.497354e-01
# 50%                                        -6.815776e-02
# 75%                                         8.539767e-01
# max                                         2.217132e+00
#
# [8 rows x 52 columns]

# %% [markdown]
# ## 8. Principal Component Analysis

# %% [markdown]
# ### 8.1 Perform PCA

# %%
# Initialize the PCA model
pca = PCA()

# Fit the PCA model to your scaled data
pca.fit(pca_df_scaled)

print("PCA model fitted successfully.")
# Out:
# PCA model fitted successfully.

# %% [markdown]
# ### 8.2 Analyze Explained Variance

# %%
# Calculate the explained variance ratio for each component
explained_variance_ratio = pca.explained_variance_ratio_

# Calculate the cumulative explained variance
cumulative_explained_variance = np.cumsum(explained_variance_ratio)

# Create the scree plot
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(explained_variance_ratio) + 1), explained_variance_ratio, marker='o', linestyle='--', label='Individual Variance')
plt.plot(range(1, len(cumulative_explained_variance) + 1), cumulative_explained_variance, marker='o', linestyle='-', label='Cumulative Variance')

plt.title('Scree Plot - Explained Variance by Principal Component')
plt.xlabel('Number of Principal Components')
plt.ylabel('Proportion of Variance Explained')
plt.xticks(range(1, len(explained_variance_ratio) + 1, 2))
plt.legend()
plt.grid(True)
plt.show()

# Print the variance explained by the first 10 components
print("Variance explained by the first few components:")
for i, variance in enumerate(explained_variance_ratio[:10]):
    print(f"  PC{i+1}: {variance:.4f} ({variance*100:.2f}%)")

print(f"\nTotal variance explained by first 10 components: {cumulative_explained_variance[9]:.4f} ({cumulative_explained_variance[9]*100:.2f}%)")
# Out:
# Variance explained by the first few components:
#   PC1: 0.6040 (60.40%)
#   PC2: 0.1192 (11.92%)
#   PC3: 0.0548 (5.48%)
#   PC4: 0.0404 (4.04%)
#   PC5: 0.0293 (2.93%)
#   PC6: 0.0217 (2.17%)
#   PC7: 0.0198 (1.98%)
#   PC8: 0.0173 (1.73%)
#   PC9: 0.0167 (1.67%)
#   PC10: 0.0124 (1.24%)
#
# Total variance explained by first 10 components: 0.9358 (93.58%)

# %% [markdown]
# ### 8.3 Examine Component Loadings

# %%
# Retrieve the component loadings from the fitted PCA model
loadings = pca.components_

# Create a DataFrame to display the loadings
# Correctly generate column names based on the number of components calculated
loadings_df = pd.DataFrame(
    loadings.T,
    columns=[f'PC{i+1}' for i in range(pca.n_components_)],
    index=pca_df_scaled.columns
)

# Display the loadings for the first 4 components
print("Loadings for the first 4 Principal Components:")
# Use .loc to safely select columns even if fewer than 4 exist
print(loadings_df.loc[:, ['PC1', 'PC2', 'PC3', 'PC4']].head()) # Show top 5 variables

# Find the strongest variables for each component
print("\n--- Top variables contributing to each component ---")

# Look at PC1
print("\nPC1:")
pc1_loadings = loadings_df['PC1'].abs().sort_values(ascending=False)
print(pc1_loadings.head(5)) # Show top 5 contributing variables

# Look at PC2
print("\nPC2:")
pc2_loadings = loadings_df['PC2'].abs().sort_values(ascending=False)
print(pc2_loadings.head(5))

# Look at PC3
print("\nPC3:")
pc3_loadings = loadings_df['PC3'].abs().sort_values(ascending=False)
print(pc3_loadings.head(5))

# Look at PC4
print("\nPC4:")
pc4_loadings = loadings_df['PC4'].abs().sort_values(ascending=False)
print(pc4_loadings.head(5))
# Out:
# Loadings for the first 4 Principal Components:
#                                PC1       PC2       PC3       PC4
# poverty_rate              0.131098  0.098661  0.002190  0.008236
# per_capita_income        -0.162514 -0.066420 -0.081657 -0.088160
# unemployment_rate         0.126130 -0.019068 -0.128037 -0.014844
# no_health_insurance_rate  0.114923 -0.031101  0.199973  0.108106
# max_aqi                   0.074430 -0.132346  0.332287  0.132699
#
# --- Top variables contributing to each component ---
#
# PC1:
# mobility_disability_among_adults              0.176146
# any_disability_among_adults                   0.175552
# independent_living_disability_among_adults    0.175253
# stroke_among_adults                           0.175057
# frequent_physical_distress_among_adults       0.174988
# Name: PC1, dtype: float64
#
# PC2:
# cancer_nonskin_or_melanoma_among_adults              0.352095
# depression_among_adults                              0.344566
# current_asthma_among_adults                          0.286033
# lack_of_social_and_emotional_support_among_adults    0.268103
# arthritis_among_adults                               0.261981
# Name: PC2, dtype: float64
#
# PC3:
# median_aqi                                0.372952
# percentile_90th_aqi                       0.356878
# feeling_socially_isolated_among_adults    0.336636
# max_aqi                                   0.332287
# days_co                                   0.326542
# Name: PC3, dtype: float64
#
# PC4:
# days_pm10                                                                               0.514807
# days_pm2_5                                                                              0.423727
# days_co                                                                                 0.402839
# taking_medicine_to_control_high_blood_pressure_among_adults_with_high_blood_pressure    0.284694
# visits_to_doctor_for_routine_checkup_within_the_past_year_among_adults                  0.250464
# Name: PC4, dtype: float64

# %% [markdown]
# ### 8.4 Transform Data to Get Scores

# %%
# Transform the scaled data into component scores
# Select the first 4 components using slicing [: , :4]
component_scores = pca.transform(pca_df_scaled)[:, :4]

# Create a new DataFrame to hold these scores
score_columns = ['PC1', 'PC2', 'PC3', 'PC4']
scores_df = pd.DataFrame(component_scores, columns=score_columns, index=master_df_final.index)

# Display the first few rows of the scores
print("Component scores calculated successfully:")
scores_df.head()
# Out:
# Component scores calculated successfully:
#         PC1       PC2       PC3       PC4
# 0 -5.850494 -2.403558 -2.629314  0.443687
# 1  0.875267  3.179759  0.883932 -0.165872
# 2 -4.769494 -1.344361 -1.174707 -1.751085
# 3 -6.492214  2.356886  2.518836  1.431946
# 4  6.993298 -1.310084 -0.306426 -0.038122

# %% [markdown]
# ## 9. Calculate EQI Score

# %% [markdown]
# ### 9.1 Combine Component Scores

# %%
# Explained variance ratios for the first 4 components
weights = pca.explained_variance_ratio_[:4]

# Calculate the EQI score as a weighted sum of the component scores
scores_df['EQI_Score'] = np.dot(scores_df[['PC1', 'PC2', 'PC3', 'PC4']], weights)

# Display the scores
print("EQI Score calculated:")
scores_df.head()
# Out:
# EQI Score calculated:
#         PC1       PC2       PC3       PC4  EQI_Score
# 0 -5.850494 -2.403558 -2.629314  0.443687  -3.946754
# 1  0.875267  3.179759  0.883932 -0.165872   0.949582
# 2 -4.769494 -1.344361 -1.174707 -1.751085  -3.176361
# 3 -6.492214  2.356886  2.518836  1.431946  -3.444594
# 4  6.993298 -1.310084 -0.306426 -0.038122   4.049675

# %% [markdown]
# ### 9.2 Merge EQI Score Back to Main DataFrame

# %%
# Add the EQI score and individual component scores to the main DataFrame
master_df_final = master_df_final.join(scores_df[['PC1', 'PC2', 'PC3', 'PC4', 'EQI_Score']])

# Confirm the new columns are added
print("EQI Score and component scores added to the final DataFrame.")
master_df_final.info()
# Out:
# EQI Score and component scores added to the final DataFrame.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 66 columns):
#  #   Column                                                                                Non-Null Count  Dtype
# ---  ------                                                                                --------------  -----
#  0   county                                                                                40 non-null     object
#  1   geography                                                                             40 non-null     object
#  2   poverty_rate                                                                          40 non-null     float64
#  3   per_capita_income                                                                     40 non-null     int64
#  4   unemployment_rate                                                                     40 non-null     float64
#  5   no_health_insurance_rate                                                              40 non-null     float64
#  6   days_with_aqi                                                                         40 non-null     int64
#  7   good_days                                                                             40 non-null     int64
#  8   moderate_days                                                                         40 non-null     int64
#  9   unhealthy_sensitive_days                                                              40 non-null     int64
#  10  unhealthy_days                                                                        40 non-null     int64
#  11  very_unhealthy_days                                                                   40 non-null     int64
#  12  hazardous_days                                                                        40 non-null     int64
#  13  max_aqi                                                                               40 non-null     int64
#  14  percentile_90th_aqi                                                                   40 non-null     int64
#  15  median_aqi                                                                            40 non-null     int64
#  16  days_co                                                                               40 non-null     int64
#  17  days_no2                                                                              40 non-null     int64
#  18  days_ozone                                                                            40 non-null     int64
#  19  days_pm2_5                                                                            40 non-null     int64
#  20  days_pm10                                                                             40 non-null     int64
#  21  all_teeth_lost_among_adults_aged_65_years                                             40 non-null     float64
#  22  any_disability_among_adults                                                           40 non-null     float64
#  23  arthritis_among_adults                                                                40 non-null     float64
#  24  binge_drinking_among_adults                                                           40 non-null     float64
#  25  cancer_nonskin_or_melanoma_among_adults                                               40 non-null     float64
#  26  cholesterol_screening_among_adults                                                    40 non-null     float64
#  27  chronic_obstructive_pulmonary_disease_among_adults                                    40 non-null     float64
#  28  cognitive_disability_among_adults                                                     40 non-null     float64
#  29  colorectal_cancer_screening_among_adults_aged_4575_years                              40 non-null     float64
#  30  coronary_heart_disease_among_adults                                                   40 non-null     float64
#  31  current_asthma_among_adults                                                           40 non-null     float64
#  32  current_cigarette_smoking_among_adults                                                40 non-null     float64
#  33  current_lack_of_health_insurance_among_adults_aged_1864_years                         40 non-null     float64
#  34  depression_among_adults                                                               40 non-null     float64
#  35  diagnosed_diabetes_among_adults                                                       40 non-null     float64
#  36  fair_or_poor_selfrated_health_status_among_adults                                     40 non-null     float64
#  37  feeling_socially_isolated_among_adults                                                40 non-null     float64
#  38  food_insecurity_in_the_past_12_months_among_adults                                    40 non-null     float64
#  39  frequent_mental_distress_among_adults                                                 40 non-null     float64
#  40  frequent_physical_distress_among_adults                                               40 non-null     float64
#  41  hearing_disability_among_adults                                                       40 non-null     float64
#  42  high_blood_pressure_among_adults                                                      40 non-null     float64
#  43  high_cholesterol_among_adults_who_have_ever_been_screened                             40 non-null     float64
#  44  housing_insecurity_in_the_past_12_months_among_adults                                 40 non-null     float64
#  45  independent_living_disability_among_adults                                            40 non-null     float64
#  46  lack_of_reliable_transportation_in_the_past_12_months_among_adults                    40 non-null     float64
#  47  lack_of_social_and_emotional_support_among_adults                                     40 non-null     float64
#  48  mammography_use_among_women_aged_5074_years                                           40 non-null     float64
#  49  mobility_disability_among_adults                                                      40 non-null     float64
#  50  no_leisuretime_physical_activity_among_adults                                         40 non-null     float64
#  51  obesity_among_adults                                                                  40 non-null     float64
#  52  received_food_stamps_in_the_past_12_months_among_adults                               40 non-null     float64
#  53  selfcare_disability_among_adults                                                      40 non-null     float64
#  54  short_sleep_duration_among_adults                                                     40 non-null     float64
#  55  stroke_among_adults                                                                   40 non-null     float64
#  56  taking_medicine_to_control_high_blood_pressure_among_adults_with_high_blood_pressure  40 non-null     float64
#  57  utility_services_shutoff_threat_in_the_past_12_months_among_adults                    40 non-null     float64
#  58  vision_disability_among_adults                                                        40 non-null     float64
#  59  visited_dentist_or_dental_clinic_in_the_past_year_among_adults                        40 non-null     float64
#  60  visits_to_doctor_for_routine_checkup_within_the_past_year_among_adults                40 non-null     float64
#  61  PC1                                                                                   40 non-null     float64
#  62  PC2                                                                                   40 non-null     float64
#  63  PC3                                                                                   40 non-null     float64
#  64  PC4                                                                                   40 non-null     float64
#  65  EQI_Score                                                                             40 non-null     float64
# dtypes: float64(48), int64(16), object(2)
# memory usage: 20.8+ KB

# %% [markdown]
# ## 10. Analysis and Visualization

# %% [markdown]
# ### 10.1 Explore EQI Scores

# %%
# Display descriptive statistics for the EQI score
print("Descriptive Statistics for EQI Score:")
print(master_df_final['EQI_Score'].describe())

# Sort the DataFrame by EQI score in descending order
df_sorted_by_eqi = master_df_final.sort_values(by='EQI_Score', ascending=False)

print("\n--- Top 5 Most Vulnerable Counties (Highest EQI Score) ---")
# Display county and EQI score for the top 5
print(df_sorted_by_eqi[['county', 'EQI_Score']].head())

print("\n--- Top 5 Least Vulnerable Counties (Lowest EQI Score) ---")
# Display county and EQI score for the bottom 5
print(df_sorted_by_eqi[['county', 'EQI_Score']].tail())
# Out:
# Descriptive Statistics for EQI Score:
# count    4.000000e+01
# mean    -8.881784e-17
# std      3.443376e+00
# min     -6.484811e+00
# 25%     -2.392247e+00
# 50%      8.627305e-02
# 75%      2.452774e+00
# max      6.231424e+00
# Name: EQI_Score, dtype: float64
#
# --- Top 5 Most Vulnerable Counties (Highest EQI Score) ---
#       county  EQI_Score
# 14    Merced   6.231424
# 6   Imperial   6.134393
# 37    Tulare   5.636551
# 7       Kern   4.912519
# 11    Madera   4.398011
#
# --- Top 5 Least Vulnerable Counties (Lowest EQI Score) ---
#            county  EQI_Score
# 0         Alameda  -3.946754
# 29    Santa Clara  -5.426957
# 27      San Mateo  -5.795910
# 24  San Francisco  -6.263817
# 12          Marin  -6.484811

# %% [markdown]
# **Interpretation: EQI Score Distribution**
#
# The calculated EQI scores range from approximately -6.5 to +6.2, centered around zero.
#
# * **Highest Scores (Most Vulnerable):** Counties like Merced, Imperial, Tulare, Kern, and Madera, primarily located in the Central Valley and southern border regions, exhibit the highest vulnerability according to the index.
# * **Lowest Scores (Least Vulnerable):** Bay Area counties such as Marin, San Francisco, San Mateo, Santa Clara, and Alameda show the lowest vulnerability scores.

# %% [markdown]
# ### 10.2 Create Choropleth Map of EQI Scores

# %%
# Load in Shapefile

try:
    ca_counties_geo = gpd.read_file('../data/california_counties/CA_Counties.shp')
    print("Shapefile loaded successfully.")
except Exception as e:
    print(f"Error loading shapefile: {e}")
    print("Please ensure the path is correct and the necessary files (.shp, .dbf, .shx) are present.")
    raise SystemExit("Shapefile loading failed.")

# Prepare Data for Merging -
ca_counties_geo['county_upper'] = ca_counties_geo['NAME'].str.upper()
master_df_final['county_upper'] = master_df_final['county'].str.upper()

# Merge Geographic Data with EQI Scores
map_data = ca_counties_geo.merge(
    master_df_final,
    on='county_upper',
    how='inner'
)

# Create the Figure and Axes
fig, ax = plt.subplots(1, 1, figsize=(9, 9))
fig.suptitle('Preliminary Environmental Quality Index (EQI) by County', fontsize = 21, fontweight='3')
fig.subplots_adjust(top=0.9, left = 0.01)
ax.axis('off')

# Plot all county outlines first
ca_counties_geo.plot(ax=ax, color='lightgrey', edgecolor='white', linewidth=0.6)

# Plot the EQI data on top
map_data.plot(
    column='EQI_Score',
    cmap='YlOrRd',
    linewidth=0.8,
    ax=ax,
    edgecolor='0.8',
    legend=True,
    legend_kwds={
        'label': None,
        'orientation': "vertical",
        'shrink': 0.85,
        'pad': 0.01
    }
)

# Add a separate, horizontal text label near the color bar
plt.text(1, 0.96,
         '    EQI Score\n    (Higher = More Vulnerability)',
         transform=ax.transAxes,
         ha='center',
         va='bottom',
         fontsize=15,
         rotation=0)

#Display map
plt.show()
# Out:
# Shapefile loaded successfully.

# %% [markdown]
# **Interpretation: Geographic Patterns of EQI**
#
# Higher vulnerability scores (darker reds) are concentrated in the Central Valley and the Imperial County region. Lower scores (lighter yellows) are predominantly found along the coast, particularly in the Bay Area and some southern coastal counties. This spatial pattern highlights significant regional disparities relevant to environmental quality and associated socioeconomic and health factors.

# %% [markdown]
# ### 10.3 Correlate EQI with Health Outcomes

# %%
# Define Variables
health_outcome_col = 'fair_or_poor_selfrated_health_status_among_adults'
health_outcome_label = 'Fair or Poor Self-Rated Health (%)'

# Create Scatter Plot with Regression Line
plt.figure(figsize=(8, 6))
sns.regplot(data=master_df_final, x='EQI_Score', y=health_outcome_col,
            line_kws={"color": "red", "lw": 2},
            scatter_kws={"alpha": 0.7})

plt.title(f'EQI Score vs. {health_outcome_label}', fontsize=14)
plt.xlabel('EQI Score (Higher = More Vulnerable)', fontsize=12)
plt.ylabel(health_outcome_label, fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# Calculate Correlation and P-value
correlation, p_value = pearsonr(master_df_final['EQI_Score'], master_df_final[health_outcome_col])

print(f"\nPearson correlation (r) between EQI Score and '{health_outcome_label}': {correlation:.3f}")
print(f"P-value: {p_value:.3e}") # Print p-value in scientific notation for very small numbers

# Interpretation of P-value
if p_value < 0.05:
    print("The correlation is statistically significant (p < 0.05).")
else:
    print("The correlation is not statistically significant (p >= 0.05).")
# Out:
# Pearson correlation (r) between EQI Score and 'Fair or Poor Self-Rated Health (%)': 0.954
# P-value: 2.083e-21
# The correlation is statistically significant (p < 0.05).

# %% [markdown]
# **Interpretation: EQI Correlation with Self-Rated Health**
#
# The scatter plot reveals a strong, positive linear relationship between the EQI score and the percentage of adults reporting fair or poor health (r ≈ 0.954). The correlation is highly statistically significant (p < 0.001).
#
# This indicates that counties with higher EQI scores consistently have populations reporting poorer overall health status. This strong correlation helps validate the EQI as a meaningful measure reflecting adverse community conditions.
